# %% [markdown]
# Este notebook contém a modelagem do OHS utilizando PINNs.

# %%
import pandas as pd

# %%
path = 'C:/Users/User/OneDrive/Documentos/doutorado/PINN/oscilador-harmonico/data/04_feature/'

# %%
df = pd.read_csv(path + 'base_01/base_fhn.csv', sep=';', encoding='latin-1')
df.head()
# Out:
#    sistema_id  simulacao_id         id_trajetoria  tempo    presas  \
# 0           0             0  sistema_0_condicao_0   0.00  3.309051
# 1           0             0  sistema_0_condicao_0   0.01  3.304549
# 2           0             0  sistema_0_condicao_0   0.02  3.300292
# 3           0             0  sistema_0_condicao_0   0.03  3.296278
# 4           0             0  sistema_0_condicao_0   0.04  3.292507
#
#    predadores                             descricao_sistema  \
# 0    4.279522  cresc:Alta, pred:Média, mort:Média, ef:Média
# 1    4.265054  cresc:Alta, pred:Média, mort:Média, ef:Média
# 2    4.250598  cresc:Alta, pred:Média, mort:Média, ef:Média
# 3    4.236156  cresc:Alta, pred:Média, mort:Média, ef:Média
# 4    4.221730  cresc:Alta, pred:Média, mort:Média, ef:Média
#
#    taxa_crescimento_a  taxa_predacao_b  taxa_mortalidade_c  taxa_eficiencia_d  \
# 0                 2.0              0.5                 1.0                0.2
# ...

# %%
df.columns
# Out:
# Index(['sistema_id', 'simulacao_id', 'id_trajetoria', 'tempo', 'presas',
#        'predadores', 'descricao_sistema', 'taxa_crescimento_a',
#        'taxa_predacao_b', 'taxa_mortalidade_c', 'taxa_eficiencia_d',
#        'frequencia_angular', 'periodo_s', 'x0', 'y0', 'presas_eq',
#        'predadores_eq', 'amplitude_presas', 'amplitude_predadores',
#        'constante_movimento'],
#       dtype='object')

# %%
df['constante_movimento'].unique()
# Out:
# array([-1.30277286, -1.30277284, -1.30277285, ..., -1.15517732,
#        -1.15517729, -1.15517728])

# %%
len(df)
# Out:
# 222500

# %%
df['tempo'].max()
# Out:
# 4.44
